# %% [markdown]
# # HW6 Diffusion Model
#
# **Sources:**
# - Github implementation [Denoising Diffusion Pytorch](https://github.com/lucidrains/denoising-diffusion-pytorch)
# - Papers on Diffusion models ([Dhariwal, Nichol, 2021], [Ho et al., 2020] ect.)

# %%
#秘密武器: https://github.com/lucidrains/stylegan2-pytorch
# !pip install stylegan2_pytorch

# %%
# !stylegan2_pytorch --data /kaggle/input/diffusion/faces/faces  --image-size 64 --num-train-steps 32000

# %%
# !stylegan2_pytorch --generate --num_generate 1000 --num-image_tiles 1 --results_dir ./picture

# %%
# %cd ./picture/default

# %%
# !tar -zcf ../../submission.tgz *ema.jpg
